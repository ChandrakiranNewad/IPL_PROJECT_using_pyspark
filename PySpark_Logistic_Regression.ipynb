# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Final_Project").getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
# Out:
# 23/02/27 16:02:59 WARN Utils: Your hostname, madhur-pc resolves to a loopback address: 127.0.1.1; using 192.168.0.105 instead (on interface wlo1)
# 23/02/27 16:02:59 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/02/27 16:03:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.105:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Final_Project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# loading the datasets

match = spark.read.option("header","true").csv("match.csv", inferSchema = True)

delivery = spark.read.option("header","true").csv("deliveries.csv", inferSchema = True)

# %% [markdown]
#  Infer schema will automatically guess the data types for each field.

# %%
match.printSchema(),delivery.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- Season: string (nullable = true)
#  |-- MatchNumber: string (nullable = true)
#  |-- Team1: string (nullable = true)
#  |-- Team2: string (nullable = true)
#  |-- Venue: string (nullable = true)
#  |-- TossWinner: string (nullable = true)
#  |-- TossDecision: string (nullable = true)
#  |-- SuperOver: string (nullable = true)
#  |-- WinningTeam: string (nullable = true)
#  |-- WonBy: string (nullable = true)
#  |-- Margin: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- Player_of_Match: string (nullable = true)
#  |-- Team1Players: string (nullable = true)
#  |-- Team2Players: string (nullable = true)
#  |-- Umpire1: string (nullable = true)
#  |-- Umpire2: string (nullable = true)
#
# root
#  |-- ID: integer (nullable = true)
#  |-- innings: integer (nullable = true)
#  |-- overs: integer (nullable = true)
#  |-- ballnumber: integer (nullable = true)
#  |-- batter: string (nullable = true)
#  |-- bowler: string (nullable = true)
#  |-- non-striker: string (nullable = true)
#  |-- extra_type: string (nullable = true)
#  |-- batsman_run: integer (nullable = true)
#  |-- extras_run: integer (nullable = true)
#  |-- total_run: integer (nullable = true)
#  |-- non_boundary: integer (nullable = true)
#  |-- isWicketDelivery: integer (nullable = true)
#  |-- player_out: string (nullable = true)
#  |-- kind: string (nullable = true)
#  |-- fielders_involved: string (nullable = true)
#  |-- BattingTeam: string (nullable = true)
# (None, None)

# %%
print(match.count(), len(match.columns))
# Out:
# 950 20

# %%
print(delivery.count(), len(delivery.columns))
# Out:
# 225954 17

# %%
match.cache(),delivery.cache()
# Out:
# (DataFrame[ID: int, City: string, Date: timestamp, Season: string, MatchNumber: string, Team1: string, Team2: string, Venue: string, TossWinner: string, TossDecision: string, SuperOver: string, WinningTeam: string, WonBy: string, Margin: string, method: string, Player_of_Match: string, Team1Players: string, Team2Players: string, Umpire1: string, Umpire2: string],
#  DataFrame[ID: int, innings: int, overs: int, ballnumber: int, batter: string, bowler: string, non-striker: string, extra_type: string, batsman_run: int, extras_run: int, total_run: int, non_boundary: int, isWicketDelivery: int, player_out: string, kind: string, fielders_involved: string, BattingTeam: string])

# %%
match.toPandas()
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad 2022-05-29     2022        Final
# 1    1312199   Ahmedabad 2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata 2022-05-25     2022   Eliminator
# 3    1312197     Kolkata 2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai 2022-05-22     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata 2008-04-20  2007/08            4
# 946   335985      Mumbai 2008-04-20  2007/08            5
# 947   335984       Delhi 2008-04-19  2007/08            3
# 948   335983  Chandigarh 2008-04-19  2007/08            2
# 949   335982   Bangalore 2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy Margin  \
# 0            bat         N               Gujarat Titans  Wickets      7
# 1          field         N             Rajasthan Royals  Wickets      7
# 2          field         N  Royal Challengers Bangalore     Runs     14
# 3          field         N               Gujarat Titans  Wickets      7
# 4            bat         N                 Punjab Kings  Wickets      5
# ..           ...       ...                          ...      ...    ...
# 945          bat         N        Kolkata Knight Riders  Wickets      5
# 946          bat         N  Royal Challengers Bangalore  Wickets      5
# 947          bat         N             Delhi Daredevils  Wickets      9
# 948          bat         N          Chennai Super Kings     Runs     33
# 949        field         N        Kolkata Knight Riders     Runs    140
#
#     method Player_of_Match                                       Team1Players  \
# 0       NA       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1       NA      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2       NA      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       NA       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4       NA   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945     NA       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946     NA      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947     NA     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948     NA      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     NA     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
delivery.toPandas()
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler         NA            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal         NA            1           0          1
# 3        JC Buttler         NA            0           0          0
# 4        JC Buttler         NA            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar         NA            1           0          1
# 225951     SB Joshi         NA            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar         NA            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0         NA      NA                NA
# 1                  0                 0         NA      NA                NA
# 2                  0                 0         NA      NA                NA
# 3                  0                 0         NA      NA                NA
# 4                  0                 0         NA      NA                NA
# ...              ...               ...        ...     ...               ...
# 225949             0                 0         NA      NA                NA
# 225950             0                 0         NA      NA                NA
# 225951             0                 0         NA      NA                NA
# 225952             0                 0         NA      NA                NA
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# creating copies of original datarames


match1 = match.select("*")

#delivery1 = delivery.select("*")

# %%
delivery1 = delivery.select("*")

# %%
match1.toPandas()
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad 2022-05-29     2022        Final
# 1    1312199   Ahmedabad 2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata 2022-05-25     2022   Eliminator
# 3    1312197     Kolkata 2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai 2022-05-22     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata 2008-04-20  2007/08            4
# 946   335985      Mumbai 2008-04-20  2007/08            5
# 947   335984       Delhi 2008-04-19  2007/08            3
# 948   335983  Chandigarh 2008-04-19  2007/08            2
# 949   335982   Bangalore 2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy Margin  \
# 0            bat         N               Gujarat Titans  Wickets      7
# 1          field         N             Rajasthan Royals  Wickets      7
# 2          field         N  Royal Challengers Bangalore     Runs     14
# 3          field         N               Gujarat Titans  Wickets      7
# 4            bat         N                 Punjab Kings  Wickets      5
# ..           ...       ...                          ...      ...    ...
# 945          bat         N        Kolkata Knight Riders  Wickets      5
# 946          bat         N  Royal Challengers Bangalore  Wickets      5
# 947          bat         N             Delhi Daredevils  Wickets      9
# 948          bat         N          Chennai Super Kings     Runs     33
# 949        field         N        Kolkata Knight Riders     Runs    140
#
#     method Player_of_Match                                       Team1Players  \
# 0       NA       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1       NA      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2       NA      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       NA       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4       NA   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945     NA       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946     NA      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947     NA     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948     NA      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     NA     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
delivery.toPandas()
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler         NA            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal         NA            1           0          1
# 3        JC Buttler         NA            0           0          0
# 4        JC Buttler         NA            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar         NA            1           0          1
# 225951     SB Joshi         NA            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar         NA            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0         NA      NA                NA
# 1                  0                 0         NA      NA                NA
# 2                  0                 0         NA      NA                NA
# 3                  0                 0         NA      NA                NA
# 4                  0                 0         NA      NA                NA
# ...              ...               ...        ...     ...               ...
# 225949             0                 0         NA      NA                NA
# 225950             0                 0         NA      NA                NA
# 225951             0                 0         NA      NA                NA
# 225952             0                 0         NA      NA                NA
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %%
match1.columns
# Out:
# ['ID',
#  'City',
#  'Date',
#  'Season',
#  'MatchNumber',
#  'Team1',
#  'Team2',
#  'Venue',
#  'TossWinner',
#  'TossDecision',
#  'SuperOver',
#  'WinningTeam',
#  'WonBy',
#  'Margin',
#  'method',
#  'Player_of_Match',
#  'Team1Players',
#  'Team2Players',
#  'Umpire1',
#  'Umpire2']

# %%
delivery1.columns
# Out:
# ['ID',
#  'innings',
#  'overs',
#  'ballnumber',
#  'batter',
#  'bowler',
#  'non-striker',
#  'extra_type',
#  'batsman_run',
#  'extras_run',
#  'total_run',
#  'non_boundary',
#  'isWicketDelivery',
#  'player_out',
#  'kind',
#  'fielders_involved',
#  'BattingTeam']

# %%
total_score_df = delivery.groupby('ID','innings').sum('total_run')

# %%
total_score_df.columns
# Out:
# ['ID', 'innings', 'sum(total_run)']

# %%
total_score_df = total_score_df.withColumnRenamed('sum(total_run)','total_run')

# %%
total_score_df.columns
# Out:
# ['ID', 'innings', 'total_run']

# %%
import pyspark.sql.functions as f
import pyspark.sql.types as T

# %%
total_score_df.show()
# Out:
# [Stage 14:>                                                         (0 + 5) / 5]
# +-------+-------+---------+
# |     ID|innings|total_run|
# +-------+-------+---------+
# |1304115|      1|      159|
# |1304102|      1|      165|
# |1304097|      2|      172|
# |1254077|      3|        7|
# |1254065|      2|      107|
# |1216512|      4|        3|
# |1304065|      2|      171|
# |1304072|      1|      199|
# |1216530|      2|      131|
# |1304069|      1|      198|
# |1254097|      1|      154|
# |1216528|      1|      167|
# |1216511|      1|      193|
# |1216544|      1|      145|
# |1254077|      4|        8|
# |1216525|      2|      132|
# |1304101|      1|      208|
# |1254094|      2|      139|
# |1216536|      2|      178|
# |1304087|      2|      150|
# +-------+-------+---------+
# only showing top 20 rows

# %%
total_score_df = total_score_df[total_score_df.innings==1]

# %%
total_score_df.show()
# Out:
# [Stage 17:>                                                         (0 + 5) / 5]
# +-------+-------+---------+
# |     ID|innings|total_run|
# +-------+-------+---------+
# |1304115|      1|      159|
# |1304102|      1|      165|
# |1304072|      1|      199|
# |1304069|      1|      198|
# |1254097|      1|      154|
# |1216528|      1|      167|
# |1216511|      1|      193|
# |1216544|      1|      145|
# |1304101|      1|      208|
# |1216492|      1|      162|
# |1304089|      1|      170|
# |1237180|      1|      189|
# |1216513|      1|      178|
# |1216501|      1|      167|
# |1304047|      1|      131|
# |1216516|      1|      164|
# |1304082|      1|       68|
# |1216534|      1|      163|
# |1216498|      1|      126|
# |1254080|      1|      171|
# +-------+-------+---------+
# only showing top 20 rows

# %%
total_score_df = total_score_df.withColumnRenamed('ID','ID_D')

# %%
match2 = match1.join(total_score_df.select('ID_D','total_run'),match1.ID == total_score_df.ID_D,"inner")

# %%
match2.cache()
# Out:
# DataFrame[ID: int, City: string, Date: timestamp, Season: string, MatchNumber: string, Team1: string, Team2: string, Venue: string, TossWinner: string, TossDecision: string, SuperOver: string, WinningTeam: string, WonBy: string, Margin: string, method: string, Player_of_Match: string, Team1Players: string, Team2Players: string, Umpire1: string, Umpire2: string, ID_D: int, total_run: bigint]

# %%
print(match2.count(),len(match2.columns))
# Out:
# [Stage 22:=================================================>    (185 + 8) / 200]
# 950 22

# %%
match2.toPandas().head(10)
# Out:
# [Stage 27:=========================================>            (155 + 9) / 200]
#         ID         City       Date   Season MatchNumber  \
# 0  1082626   Chandigarh 2017-04-30     2017          36
# 1   829711      Chennai 2015-04-11     2015           4
# 2   734021    Hyderabad 2014-05-20     2014          46
# 3   733997      Cuttack 2014-05-11     2014          34
# 4   501203      Kolkata 2011-04-11     2011           6
# 5   419132       Mumbai 2010-03-30  2009/10          27
# 6   392196       Durban 2009-04-27     2009          16
# 7   336009        Delhi 2008-05-08  2007/08          28
# 8  1304115       Mumbai 2022-05-21     2022          69
# 9  1304102  Navi Mumbai 2022-05-09     2022          56
#
#                    Team1                        Team2  \
# 0        Kings XI Punjab             Delhi Daredevils
# 1    Chennai Super Kings          Sunrisers Hyderabad
# 2    Sunrisers Hyderabad  Royal Challengers Bangalore
# 3        Kings XI Punjab        Kolkata Knight Riders
# 4  Kolkata Knight Riders              Deccan Chargers
# 5         Mumbai Indians              Kings XI Punjab
# 6    Chennai Super Kings              Deccan Chargers
# 7       Delhi Daredevils          Chennai Super Kings
# 8         Delhi Capitals               Mumbai Indians
# 9  Kolkata Knight Riders               Mumbai Indians
#
#                                                Venue  \
# 0  Punjab Cricket Association IS Bindra Stadium, ...
# 1                    MA Chidambaram Stadium, Chepauk
# 2          Rajiv Gandhi International Stadium, Uppal
# 3                                   Barabati Stadium
# 4                                       Eden Gardens
# 5                                  Brabourne Stadium
# 6                                          Kingsmead
# 7                                   Feroz Shah Kotla
# 8                           Wankhede Stadium, Mumbai
# 9                 Dr DY Patil Sports Academy, Mumbai
#
#                     TossWinner TossDecision  ...    WonBy Margin method  \
# 0              Kings XI Punjab        field  ...  Wickets     10     NA
# 1          Chennai Super Kings          bat  ...     Runs     45     NA
# 2  Royal Challengers Bangalore          bat  ...  Wickets      7     NA
# 3        Kolkata Knight Riders        field  ...  Wickets      9     NA
# 4        Kolkata Knight Riders          bat  ...     Runs      9     NA
# 5               Mumbai Indians        field  ...  Wickets      4     NA
# 6              Deccan Chargers        field  ...  Wickets      6     NA
# 7          Chennai Super Kings        field  ...  Wickets      4     NA
# 8               Mumbai Indians        field  ...  Wickets      5     NA
# 9               Mumbai Indians        field  ...     Runs     52     NA
#
#   Player_of_Match                                       Team1Players  \
# 0  Sandeep Sharma  ['MJ Guptill', 'HM Amla', 'M Vohra', 'SE Marsh...
# 1     BB McCullum  ['DR Smith', 'BB McCullum', 'SK Raina', 'MS Dh...
# 2       DA Warner  ['S Dhawan', 'DA Warner', 'NV Ojha', 'AJ Finch...
# 3       G Gambhir  ['V Sehwag', 'Mandeep Singh', 'WP Saha', 'GJ M...
# 4       JH Kallis  ['JH Kallis', 'MS Bisla', 'G Gambhir', 'MK Tiw...
# 5      SL Malinga  ['S Dhawan', 'SR Tendulkar', 'KA Pollard', 'SS...
# 6        HH Gibbs  ['PA Patel', 'ML Hayden', 'SK Raina', 'MS Dhon...
# 7        MS Dhoni  ['G Gambhir', 'V Sehwag', 'AB de Villiers', 'S...
# 8       JJ Bumrah  ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...
# 9       JJ Bumrah  ['VR Iyer', 'AM Rahane', 'N Rana', 'SS Iyer', ...
#
#                                         Team2Players         Umpire1  \
# 0  ['SV Samson', 'SW Billings', 'KK Nair', 'SS Iy...        YC Barde
# 1  ['DA Warner', 'S Dhawan', 'KL Rahul', 'NV Ojha...  RK Illingworth
# 2  ['CH Gayle', 'PA Patel', 'V Kohli', 'Yuvraj Si...    AK Chaudhary
# 3  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'JH K...        NJ Llong
# 4  ['S Dhawan', 'IR Jaggi', 'B Chipli', 'KC Sanga...     RE Koertzen
# 5  ['RS Bopara', 'SE Marsh', 'MS Bisla', 'DPMD Ja...     BR Doctrove
# 6  ['AC Gilchrist', 'HH Gibbs', 'VVS Laxman', 'RG...       IL Howell
# 7  ['S Vidyut', 'SP Fleming', 'MS Dhoni', 'SK Rai...       Aleem Dar
# 8  ['Ishan Kishan', 'RG Sharma', 'D Brevis', 'Til...     Nitin Menon
# 9  ['RG Sharma', 'Ishan Kishan', 'Tilak Varma', '...     CB Gaffaney
#
#             Umpire2     ID_D total_run
# 0         CK Nandan  1082626        67
# 1       VA Kulkarni   829711       209
# 2          NJ Llong   734021       160
# 3         CK Nandan   733997       149
# 4       SK Tarapore   501203       163
# 5       SK Tarapore   419132       163
# 6    TH Wijewardene   392196       165
# 7         RB Tiffin   336009       187
# 8      Tapan Sharma  1304115       159
# 9  GR Sadashiv Iyer  1304102       165
#
# [10 rows x 22 columns]

# %%
match2.select('Team1').distinct().show(truncate=False)
# Out:
# [Stage 29:===============================================>     (179 + 10) / 200]
# +---------------------------+
# |Team1                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Kolkata Knight Riders      |
# |Kings XI Punjab            |
# |Delhi Daredevils           |
# |Mumbai Indians             |
# |Delhi Capitals             |
# |Lucknow Super Giants       |
# |Rajasthan Royals           |
# |Punjab Kings               |
# |Royal Challengers Bangalore|
# |Deccan Chargers            |
# |Gujarat Lions              |
# |Rising Pune Supergiant     |
# |Pune Warriors              |
# |Kochi Tuskers Kerala       |
# |Gujarat Titans             |
# |Rising Pune Supergiants    |
# +---------------------------+

# %%
teams = ['Rajasthan Royals', 'Royal Challengers Bangalore',
       'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
       'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
       'Punjab Kings', 'Mumbai Indians']

# %%
from pyspark.sql.functions import regexp_replace

# %%
match2=match2.withColumn('Team1',regexp_replace('Team1','Delhi Daredevils','Delhi Capitals'))
match2=match2.withColumn('Team2',regexp_replace('Team2','Delhi Daredevils','Delhi Capitals'))

match2=match2.withColumn('Team1',regexp_replace('Team1','Deccan Chargers','Sunrisers Hyderabad'))
match2=match2.withColumn('Team2',regexp_replace('Team2','Deccan Chargers','Sunrisers Hyderabad'))

match2=match2.withColumn('Team1',regexp_replace('Team1','Kings XI Punjab','Punjab Kings'))
match2=match2.withColumn('Team2',regexp_replace('Team2','Kings XI Punjab','Punjab Kings'))

# %%
match2.select('Team1').distinct().show(truncate=False)
# Out:
# [Stage 34:==============================================>       (174 + 8) / 200]
# +---------------------------+
# |Team1                      |
# +---------------------------+
# |Sunrisers Hyderabad        |
# |Chennai Super Kings        |
# |Kolkata Knight Riders      |
# |Punjab Kings               |
# |Delhi Capitals             |
# |Mumbai Indians             |
# |Lucknow Super Giants       |
# |Rajasthan Royals           |
# |Royal Challengers Bangalore|
# |Gujarat Lions              |
# |Rising Pune Supergiant     |
# |Pune Warriors              |
# |Kochi Tuskers Kerala       |
# |Gujarat Titans             |
# |Rising Pune Supergiants    |
# +---------------------------+

# %%
match2=match2[match2.Team1.isin(teams)]
match2=match2[match2.Team2.isin(teams)]

delivery2 = delivery1[delivery1.BattingTeam.isin(teams)]

# %%
print(match2.count(),len(match2.columns))
# Out:
# [Stage 39:============================================>         (164 + 8) / 200]
# 835 22

# %%
match2 = match2.withColumnRenamed('ID','ID_M')

# %%
match2 = match2.withColumnRenamed('total_run','target_score')

# %%
match2 = match2.withColumn("target_score", match2.target_score + 1)

# %%
match2.toPandas().head()
# Out:
#       ID_M        City       Date Season MatchNumber                  Team1  \
# 0  1082626  Chandigarh 2017-04-30   2017          36           Punjab Kings
# 1   829711     Chennai 2015-04-11   2015           4    Chennai Super Kings
# 2   734021   Hyderabad 2014-05-20   2014          46    Sunrisers Hyderabad
# 3   733997     Cuttack 2014-05-11   2014          34           Punjab Kings
# 4   501203     Kolkata 2011-04-11   2011           6  Kolkata Knight Riders
#
#                          Team2  \
# 0               Delhi Capitals
# 1          Sunrisers Hyderabad
# 2  Royal Challengers Bangalore
# 3        Kolkata Knight Riders
# 4          Sunrisers Hyderabad
#
#                                                Venue  \
# 0  Punjab Cricket Association IS Bindra Stadium, ...
# 1                    MA Chidambaram Stadium, Chepauk
# 2          Rajiv Gandhi International Stadium, Uppal
# 3                                   Barabati Stadium
# 4                                       Eden Gardens
#
#                     TossWinner TossDecision  ...    WonBy Margin method  \
# 0              Kings XI Punjab        field  ...  Wickets     10     NA
# 1          Chennai Super Kings          bat  ...     Runs     45     NA
# 2  Royal Challengers Bangalore          bat  ...  Wickets      7     NA
# 3        Kolkata Knight Riders        field  ...  Wickets      9     NA
# 4        Kolkata Knight Riders          bat  ...     Runs      9     NA
#
#   Player_of_Match                                       Team1Players  \
# 0  Sandeep Sharma  ['MJ Guptill', 'HM Amla', 'M Vohra', 'SE Marsh...
# 1     BB McCullum  ['DR Smith', 'BB McCullum', 'SK Raina', 'MS Dh...
# 2       DA Warner  ['S Dhawan', 'DA Warner', 'NV Ojha', 'AJ Finch...
# 3       G Gambhir  ['V Sehwag', 'Mandeep Singh', 'WP Saha', 'GJ M...
# 4       JH Kallis  ['JH Kallis', 'MS Bisla', 'G Gambhir', 'MK Tiw...
#
#                                         Team2Players         Umpire1  \
# 0  ['SV Samson', 'SW Billings', 'KK Nair', 'SS Iy...        YC Barde
# 1  ['DA Warner', 'S Dhawan', 'KL Rahul', 'NV Ojha...  RK Illingworth
# 2  ['CH Gayle', 'PA Patel', 'V Kohli', 'Yuvraj Si...    AK Chaudhary
# 3  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'JH K...        NJ Llong
# 4  ['S Dhawan', 'IR Jaggi', 'B Chipli', 'KC Sanga...     RE Koertzen
#
#        Umpire2     ID_D target_score
# 0    CK Nandan  1082626           68
# 1  VA Kulkarni   829711          210
# 2     NJ Llong   734021          161
# 3    CK Nandan   733997          150
# 4  SK Tarapore   501203          164
#
# [5 rows x 22 columns]

# %%
match2 = match2[match2.method!='D/L']

# %%
print(match2.count(),len(match2.columns))
# Out:
# [Stage 46:=============================================>        (168 + 8) / 200]
# 820 22

# %%
match2 = match2['ID_M','City','WinningTeam','target_score','Team1', 'Team2']

# %%
match2.toPandas()
# Out:
#         ID_M        City            WinningTeam  target_score  \
# 0    1082626  Chandigarh        Kings XI Punjab            68
# 1     829711     Chennai    Chennai Super Kings           210
# 2     734021   Hyderabad    Sunrisers Hyderabad           161
# 3     733997     Cuttack  Kolkata Knight Riders           150
# 4     501203     Kolkata  Kolkata Knight Riders           164
# ..       ...         ...                    ...           ...
# 815   392225      Durban       Rajasthan Royals           146
# 816  1216496          NA       Rajasthan Royals           217
# 817  1136577        Pune    Chennai Super Kings           205
# 818   734027     Kolkata  Kolkata Knight Riders           196
# 819   548377      Jaipur         Mumbai Indians           163
#
#                      Team1                        Team2
# 0             Punjab Kings               Delhi Capitals
# 1      Chennai Super Kings          Sunrisers Hyderabad
# 2      Sunrisers Hyderabad  Royal Challengers Bangalore
# 3             Punjab Kings        Kolkata Knight Riders
# 4    Kolkata Knight Riders          Sunrisers Hyderabad
# ..                     ...                          ...
# 815         Mumbai Indians             Rajasthan Royals
# 816       Rajasthan Royals          Chennai Super Kings
# 817    Chennai Super Kings             Rajasthan Royals
# 818  Kolkata Knight Riders  Royal Challengers Bangalore
# 819       Rajasthan Royals               Mumbai Indians
#
# [820 rows x 6 columns]

# %%
delivery2.toPandas()
# Out:
# [Stage 52:=======================>                                  (2 + 3) / 5]
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 161412   335982        2     14           5      P Kumar        I Sharma
# 161413   335982        2     14           6     SB Joshi        I Sharma
# 161414   335982        2     14           7      P Kumar        I Sharma
# 161415   335982        2     15           1     SB Joshi       LR Shukla
# 161416   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler         NA            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal         NA            1           0          1
# 3        JC Buttler         NA            0           0          0
# 4        JC Buttler         NA            0           0          0
# ...             ...        ...          ...         ...        ...
# 161412     SB Joshi    legbyes            0           1          1
# 161413      P Kumar         NA            1           0          1
# 161414     SB Joshi         NA            0           0          0
# 161415      P Kumar      wides            0           1          1
# 161416      P Kumar         NA            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0         NA      NA                NA
# 1                  0                 0         NA      NA                NA
# 2                  0                 0         NA      NA                NA
# 3                  0                 0         NA      NA                NA
# 4                  0                 0         NA      NA                NA
# ...              ...               ...        ...     ...               ...
# 161412             0                 0         NA      NA                NA
# 161413             0                 0         NA      NA                NA
# 161414             0                 0         NA      NA                NA
# 161415             0                 0         NA      NA                NA
# 161416             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 161412  Royal Challengers Bangalore
# 161413  Royal Challengers Bangalore
# 161414  Royal Challengers Bangalore
# 161415  Royal Challengers Bangalore
# 161416  Royal Challengers Bangalore
#
# [161417 rows x 17 columns]

# %%
delivery2 = match2.join(delivery2,match2.ID_M==delivery2.ID,"inner")

# %%
delivery2.cache()
# Out:
# DataFrame[ID_M: int, City: string, WinningTeam: string, target_score: bigint, Team1: string, Team2: string, ID: int, innings: int, overs: int, ballnumber: int, batter: string, bowler: string, non-striker: string, extra_type: string, batsman_run: int, extras_run: int, total_run: int, non_boundary: int, isWicketDelivery: int, player_out: string, kind: string, fielders_involved: string, BattingTeam: string]

# %%
print(delivery2.count(),len(delivery2.columns))
# Out:
# [Stage 55:==============================================>           (4 + 1) / 5]
# 151092 23

# %%
delivery2.toPandas()
# Out:
#            ID_M       City            WinningTeam  target_score  \
# 0       1312200  Ahmedabad         Gujarat Titans           131
# 1       1312200  Ahmedabad         Gujarat Titans           131
# 2       1312200  Ahmedabad         Gujarat Titans           131
# 3       1312200  Ahmedabad         Gujarat Titans           131
# 4       1312200  Ahmedabad         Gujarat Titans           131
# ...         ...        ...                    ...           ...
# 151087   335982  Bangalore  Kolkata Knight Riders           223
# 151088   335982  Bangalore  Kolkata Knight Riders           223
# 151089   335982  Bangalore  Kolkata Knight Riders           223
# 151090   335982  Bangalore  Kolkata Knight Riders           223
# 151091   335982  Bangalore  Kolkata Knight Riders           223
#
#                               Team1                  Team2       ID  innings  \
# 0                  Rajasthan Royals         Gujarat Titans  1312200        1
# 1                  Rajasthan Royals         Gujarat Titans  1312200        1
# 2                  Rajasthan Royals         Gujarat Titans  1312200        1
# 3                  Rajasthan Royals         Gujarat Titans  1312200        1
# 4                  Rajasthan Royals         Gujarat Titans  1312200        1
# ...                             ...                    ...      ...      ...
# 151087  Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 151088  Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 151089  Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 151090  Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 151091  Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
#
#         overs  ballnumber  ... extra_type batsman_run extras_run total_run  \
# 0           0           1  ...         NA           0          0         0
# 1           0           2  ...    legbyes           0          1         1
# 2           0           3  ...         NA           1          0         1
# 3           0           4  ...         NA           0          0         0
# 4           0           5  ...         NA           0          0         0
# ...       ...         ...  ...        ...         ...        ...       ...
# 151087     14           5  ...    legbyes           0          1         1
# 151088     14           6  ...         NA           1          0         1
# 151089     14           7  ...         NA           0          0         0
# 151090     15           1  ...      wides           0          1         1
# 151091     15           2  ...         NA           0          0         0
#
#         non_boundary  isWicketDelivery  player_out    kind  fielders_involved  \
# 0                  0                 0          NA      NA                 NA
# 1                  0                 0          NA      NA                 NA
# 2                  0                 0          NA      NA                 NA
# 3                  0                 0          NA      NA                 NA
# 4                  0                 0          NA      NA                 NA
# ...              ...               ...         ...     ...                ...
# 151087             0                 0          NA      NA                 NA
# 151088             0                 0          NA      NA                 NA
# 151089             0                 0          NA      NA                 NA
# 151090             0                 0          NA      NA                 NA
# 151091             0                 1    SB Joshi  caught        BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 151087  Royal Challengers Bangalore
# 151088  Royal Challengers Bangalore
# 151089  Royal Challengers Bangalore
# 151090  Royal Challengers Bangalore
# 151091  Royal Challengers Bangalore
#
# [151092 rows x 23 columns]

# %%
delivery2 = delivery2[delivery2.innings==2]

# %%
from pyspark.sql.window import Window
import sys

windowval=Window.partitionBy('ID_M').rowsBetween(-sys.maxsize, 0)

# %%
delivery2 = delivery2.withColumn('current_score',f.sum('total_run').over(windowval))

# %%
delivery2 = delivery2.withColumn('runs_left',((delivery2['target_score'])-delivery2['current_score']))

# %%
delivery2.toPandas()
# Out:
#           ID_M       City            WinningTeam  target_score  \
# 0       335982  Bangalore  Kolkata Knight Riders           223
# 1       335982  Bangalore  Kolkata Knight Riders           223
# 2       335982  Bangalore  Kolkata Knight Riders           223
# 3       335982  Bangalore  Kolkata Knight Riders           223
# 4       335982  Bangalore  Kolkata Knight Riders           223
# ...        ...        ...                    ...           ...
# 72758  1312199  Ahmedabad       Rajasthan Royals           158
# 72759  1312199  Ahmedabad       Rajasthan Royals           158
# 72760  1312199  Ahmedabad       Rajasthan Royals           158
# 72761  1312199  Ahmedabad       Rajasthan Royals           158
# 72762  1312199  Ahmedabad       Rajasthan Royals           158
#
#                              Team1                  Team2       ID  innings  \
# 0      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 1      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 2      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 3      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 4      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# ...                            ...                    ...      ...      ...
# 72758  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72759  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72760  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72761  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72762  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
#
#        overs  ballnumber  ... extras_run total_run non_boundary  \
# 0          0           1  ...          0         1            0
# 1          0           2  ...          1         1            0
# 2          0           3  ...          0         0            0
# 3          0           4  ...          0         1            0
# 4          0           5  ...          0         1            0
# ...      ...         ...  ...        ...       ...          ...
# 72758     17           3  ...          0         1            0
# 72759     17           4  ...          0         1            0
# 72760     17           5  ...          0         2            0
# 72761     17           6  ...          0         1            0
# 72762     18           1  ...          0         6            0
#
#       isWicketDelivery  player_out  kind  fielders_involved  \
# 0                    0          NA    NA                 NA
# 1                    0          NA    NA                 NA
# 2                    0          NA    NA                 NA
# 3                    0          NA    NA                 NA
# 4                    0          NA    NA                 NA
# ...                ...         ...   ...                ...
# 72758                0          NA    NA                 NA
# 72759                0          NA    NA                 NA
# 72760                0          NA    NA                 NA
# 72761                0          NA    NA                 NA
# 72762                0          NA    NA                 NA
#
#                        BattingTeam  current_score runs_left
# 0      Royal Challengers Bangalore              1       222
# 1      Royal Challengers Bangalore              2       221
# 2      Royal Challengers Bangalore              2       221
# 3      Royal Challengers Bangalore              3       220
# 4      Royal Challengers Bangalore              4       219
# ...                            ...            ...       ...
# 72758             Rajasthan Royals            151         7
# 72759             Rajasthan Royals            152         6
# 72760             Rajasthan Royals            154         4
# 72761             Rajasthan Royals            155         3
# 72762             Rajasthan Royals            161        -3
#
# [72763 rows x 25 columns]

# %%
delivery2.withColumn('balls_left',126-(((delivery2['overs']+1)*6)+delivery2['ballnumber'])).toPandas()
# Out:
#           ID_M       City            WinningTeam  target_score  \
# 0       335982  Bangalore  Kolkata Knight Riders           223
# 1       335982  Bangalore  Kolkata Knight Riders           223
# 2       335982  Bangalore  Kolkata Knight Riders           223
# 3       335982  Bangalore  Kolkata Knight Riders           223
# 4       335982  Bangalore  Kolkata Knight Riders           223
# ...        ...        ...                    ...           ...
# 72758  1312199  Ahmedabad       Rajasthan Royals           158
# 72759  1312199  Ahmedabad       Rajasthan Royals           158
# 72760  1312199  Ahmedabad       Rajasthan Royals           158
# 72761  1312199  Ahmedabad       Rajasthan Royals           158
# 72762  1312199  Ahmedabad       Rajasthan Royals           158
#
#                              Team1                  Team2       ID  innings  \
# 0      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 1      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 2      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 3      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 4      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# ...                            ...                    ...      ...      ...
# 72758  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72759  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72760  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72761  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72762  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
#
#        overs  ballnumber  ... total_run non_boundary isWicketDelivery  \
# 0          0           1  ...         1            0                0
# 1          0           2  ...         1            0                0
# 2          0           3  ...         0            0                0
# 3          0           4  ...         1            0                0
# 4          0           5  ...         1            0                0
# ...      ...         ...  ...       ...          ...              ...
# 72758     17           3  ...         1            0                0
# 72759     17           4  ...         1            0                0
# 72760     17           5  ...         2            0                0
# 72761     17           6  ...         1            0                0
# 72762     18           1  ...         6            0                0
#
#       player_out  kind  fielders_involved                  BattingTeam  \
# 0             NA    NA                 NA  Royal Challengers Bangalore
# 1             NA    NA                 NA  Royal Challengers Bangalore
# 2             NA    NA                 NA  Royal Challengers Bangalore
# 3             NA    NA                 NA  Royal Challengers Bangalore
# 4             NA    NA                 NA  Royal Challengers Bangalore
# ...          ...   ...                ...                          ...
# 72758         NA    NA                 NA             Rajasthan Royals
# 72759         NA    NA                 NA             Rajasthan Royals
# 72760         NA    NA                 NA             Rajasthan Royals
# 72761         NA    NA                 NA             Rajasthan Royals
# 72762         NA    NA                 NA             Rajasthan Royals
#
#        current_score  runs_left balls_left
# 0                  1        222        119
# 1                  2        221        118
# 2                  2        221        117
# 3                  3        220        116
# 4                  4        219        115
# ...              ...        ...        ...
# 72758            151          7         15
# 72759            152          6         14
# 72760            154          4         13
# 72761            155          3         12
# 72762            161         -3         11
#
# [72763 rows x 26 columns]

# %%
delivery2 = delivery2.withColumn('balls_left',126-(((delivery2['overs']+1)*6)+delivery2['ballnumber']))

# %%
delivery2.groupby('ID_M').sum('isWicketDelivery').toPandas()
# Out:
#         ID_M  sum(isWicketDelivery)
# 0    1254081                      3
# 1    1304099                     10
# 2    1304102                     10
# 3    1254064                      7
# 4    1304059                      6
# ..       ...                    ...
# 622   336011                      2
# 623   419122                      3
# 624   392221                      4
# 625   336028                     10
# 626   336037                      3
#
# [627 rows x 2 columns]

# %%
delivery2 = delivery2.withColumn('wickets',f.sum('isWicketDelivery').over(windowval))

# %%
delivery2.withColumn('wickets_left',(10-f.col('wickets')))
# Out:
# DataFrame[ID_M: int, City: string, WinningTeam: string, target_score: bigint, Team1: string, Team2: string, ID: int, innings: int, overs: int, ballnumber: int, batter: string, bowler: string, non-striker: string, extra_type: string, batsman_run: int, extras_run: int, total_run: int, non_boundary: int, isWicketDelivery: int, player_out: string, kind: string, fielders_involved: string, BattingTeam: string, current_score: bigint, runs_left: bigint, balls_left: int, wickets: bigint, wickets_left: bigint]

# %%
delivery2 = delivery2.withColumn('wickets_left',(10-f.col('wickets')))

# %%
delivery2.toPandas().tail(10)
# Out:
#           ID_M       City       WinningTeam  target_score  \
# 72753  1312199  Ahmedabad  Rajasthan Royals           158
# 72754  1312199  Ahmedabad  Rajasthan Royals           158
# 72755  1312199  Ahmedabad  Rajasthan Royals           158
# 72756  1312199  Ahmedabad  Rajasthan Royals           158
# 72757  1312199  Ahmedabad  Rajasthan Royals           158
# 72758  1312199  Ahmedabad  Rajasthan Royals           158
# 72759  1312199  Ahmedabad  Rajasthan Royals           158
# 72760  1312199  Ahmedabad  Rajasthan Royals           158
# 72761  1312199  Ahmedabad  Rajasthan Royals           158
# 72762  1312199  Ahmedabad  Rajasthan Royals           158
#
#                              Team1             Team2       ID  innings  overs  \
# 72753  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     16
# 72754  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     16
# 72755  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     16
# 72756  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     17
# 72757  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     17
# 72758  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     17
# 72759  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     17
# 72760  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     17
# 72761  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     17
# 72762  Royal Challengers Bangalore  Rajasthan Royals  1312199        2     18
#
#        ballnumber  ... isWicketDelivery  player_out    kind fielders_involved  \
# 72753           4  ...                0          NA      NA                NA
# 72754           5  ...                1  D Padikkal  caught        KD Karthik
# 72755           6  ...                0          NA      NA                NA
# 72756           1  ...                0          NA      NA                NA
# 72757           2  ...                0          NA      NA                NA
# 72758           3  ...                0          NA      NA                NA
# 72759           4  ...                0          NA      NA                NA
# 72760           5  ...                0          NA      NA                NA
# 72761           6  ...                0          NA      NA                NA
# 72762           1  ...                0          NA      NA                NA
#
#             BattingTeam  current_score  runs_left  balls_left  wickets  \
# 72753  Rajasthan Royals            148         10          20        2
# 72754  Rajasthan Royals            148         10          19        3
# 72755  Rajasthan Royals            148         10          18        3
# 72756  Rajasthan Royals            149          9          17        3
# 72757  Rajasthan Royals            150          8          16        3
# 72758  Rajasthan Royals            151          7          15        3
# 72759  Rajasthan Royals            152          6          14        3
# 72760  Rajasthan Royals            154          4          13        3
# 72761  Rajasthan Royals            155          3          12        3
# 72762  Rajasthan Royals            161         -3          11        3
#
#       wickets_left
# 72753            8
# 72754            7
# 72755            7
# 72756            7
# 72757            7
# 72758            7
# 72759            7
# 72760            7
# 72761            7
# 72762            7
#
# [10 rows x 28 columns]

# %%
delivery2 = delivery2.drop('wickets')

# %%
delivery2 = delivery2.withColumn('current_run_rate',((delivery2['current_score']/(120-delivery2['balls_left']))*6))

# %%
delivery2 = delivery2.withColumn('required_run_rate', ((delivery2['runs_left'] * 6)/delivery2['balls_left']))

# %%
from pyspark.sql.types import IntegerType,StringType
from pyspark.sql.functions import udf,col

# %%
def BowlingTeam(Team1,Team2,BattingTeam):
    if Team2== BattingTeam:
        return Team1
    else:
        return Team2

# %%
spark.udf.register(name='BowlingTeam',f=BowlingTeam,returnType=StringType())
# Out:
# <function __main__.BowlingTeam(Team1, Team2, BattingTeam)>

# %%
delivery2.createOrReplaceTempView('delivery')

# %%
spark.sql('select *, BowlingTeam(Team1,Team2,BattingTeam) as BowlingTeam from delivery').toPandas()
# Out:
#           ID_M       City            WinningTeam  target_score  \
# 0       335982  Bangalore  Kolkata Knight Riders           223
# 1       335982  Bangalore  Kolkata Knight Riders           223
# 2       335982  Bangalore  Kolkata Knight Riders           223
# 3       335982  Bangalore  Kolkata Knight Riders           223
# 4       335982  Bangalore  Kolkata Knight Riders           223
# ...        ...        ...                    ...           ...
# 72758  1312199  Ahmedabad       Rajasthan Royals           158
# 72759  1312199  Ahmedabad       Rajasthan Royals           158
# 72760  1312199  Ahmedabad       Rajasthan Royals           158
# 72761  1312199  Ahmedabad       Rajasthan Royals           158
# 72762  1312199  Ahmedabad       Rajasthan Royals           158
#
#                              Team1                  Team2       ID  innings  \
# 0      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 1      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 2      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 3      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 4      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# ...                            ...                    ...      ...      ...
# 72758  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72759  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72760  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72761  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72762  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
#
#        overs  ballnumber  ... kind fielders_involved  \
# 0          0           1  ...   NA                NA
# 1          0           2  ...   NA                NA
# 2          0           3  ...   NA                NA
# 3          0           4  ...   NA                NA
# 4          0           5  ...   NA                NA
# ...      ...         ...  ...  ...               ...
# 72758     17           3  ...   NA                NA
# 72759     17           4  ...   NA                NA
# 72760     17           5  ...   NA                NA
# 72761     17           6  ...   NA                NA
# 72762     18           1  ...   NA                NA
#
#                        BattingTeam current_score  runs_left  balls_left  \
# 0      Royal Challengers Bangalore             1        222         119
# 1      Royal Challengers Bangalore             2        221         118
# 2      Royal Challengers Bangalore             2        221         117
# 3      Royal Challengers Bangalore             3        220         116
# 4      Royal Challengers Bangalore             4        219         115
# ...                            ...           ...        ...         ...
# 72758             Rajasthan Royals           151          7          15
# 72759             Rajasthan Royals           152          6          14
# 72760             Rajasthan Royals           154          4          13
# 72761             Rajasthan Royals           155          3          12
# 72762             Rajasthan Royals           161         -3          11
#
#        wickets_left  current_run_rate  required_run_rate  \
# 0                10          6.000000          11.193277
# 1                10          6.000000          11.237288
# 2                10          4.000000          11.333333
# 3                10          4.500000          11.379310
# 4                10          4.800000          11.426087
# ...             ...               ...                ...
# 72758             7          8.628571           2.800000
# 72759             7          8.603774           2.571429
# 72760             7          8.635514           1.846154
# 72761             7          8.611111           1.500000
# 72762             7          8.862385          -1.636364
#
#                        BowlingTeam
# 0            Kolkata Knight Riders
# 1            Kolkata Knight Riders
# 2            Kolkata Knight Riders
# 3            Kolkata Knight Riders
# 4            Kolkata Knight Riders
# ...                            ...
# 72758  Royal Challengers Bangalore
# 72759  Royal Challengers Bangalore
# 72760  Royal Challengers Bangalore
# 72761  Royal Challengers Bangalore
# 72762  Royal Challengers Bangalore
#
# [72763 rows x 30 columns]

# %%
delivery2 = spark.sql('select *, BowlingTeam(Team1,Team2,BattingTeam) as BowlingTeam from delivery')

# %%
# to check if the batting team and bowling teams are different in each row

delivery2[delivery2.BattingTeam == delivery2.BowlingTeam].toPandas()
# Out:
# Empty DataFrame
# Columns: [ID_M, City, WinningTeam, target_score, Team1, Team2, ID, innings, overs, ballnumber, batter, bowler, non-striker, extra_type, batsman_run, extras_run, total_run, non_boundary, isWicketDelivery, player_out, kind, fielders_involved, BattingTeam, current_score, runs_left, balls_left, wickets_left, current_run_rate, required_run_rate, BowlingTeam]
# Index: []
#
# [0 rows x 30 columns]

# %%
delivery2.createOrReplaceTempView('delivery')

# %%
def result(BattingTeam,WinningTeam):
    return 1 if BattingTeam == WinningTeam else 0

# %%
spark.udf.register(name='result', f = result, returnType=IntegerType())
# Out:
# <function __main__.result(BattingTeam, WinningTeam)>

# %%
spark.sql('select *,result(BattingTeam,WinningTeam) as result from delivery').toPandas()
# Out:
#           ID_M       City            WinningTeam  target_score  \
# 0       335982  Bangalore  Kolkata Knight Riders           223
# 1       335982  Bangalore  Kolkata Knight Riders           223
# 2       335982  Bangalore  Kolkata Knight Riders           223
# 3       335982  Bangalore  Kolkata Knight Riders           223
# 4       335982  Bangalore  Kolkata Knight Riders           223
# ...        ...        ...                    ...           ...
# 72758  1312199  Ahmedabad       Rajasthan Royals           158
# 72759  1312199  Ahmedabad       Rajasthan Royals           158
# 72760  1312199  Ahmedabad       Rajasthan Royals           158
# 72761  1312199  Ahmedabad       Rajasthan Royals           158
# 72762  1312199  Ahmedabad       Rajasthan Royals           158
#
#                              Team1                  Team2       ID  innings  \
# 0      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 1      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 2      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 3      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# 4      Royal Challengers Bangalore  Kolkata Knight Riders   335982        2
# ...                            ...                    ...      ...      ...
# 72758  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72759  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72760  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72761  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
# 72762  Royal Challengers Bangalore       Rajasthan Royals  1312199        2
#
#        overs  ballnumber  ... fielders_involved                  BattingTeam  \
# 0          0           1  ...                NA  Royal Challengers Bangalore
# 1          0           2  ...                NA  Royal Challengers Bangalore
# 2          0           3  ...                NA  Royal Challengers Bangalore
# 3          0           4  ...                NA  Royal Challengers Bangalore
# 4          0           5  ...                NA  Royal Challengers Bangalore
# ...      ...         ...  ...               ...                          ...
# 72758     17           3  ...                NA             Rajasthan Royals
# 72759     17           4  ...                NA             Rajasthan Royals
# 72760     17           5  ...                NA             Rajasthan Royals
# 72761     17           6  ...                NA             Rajasthan Royals
# 72762     18           1  ...                NA             Rajasthan Royals
#
#       current_score runs_left  balls_left  wickets_left  current_run_rate  \
# 0                 1       222         119            10          6.000000
# 1                 2       221         118            10          6.000000
# 2                 2       221         117            10          4.000000
# 3                 3       220         116            10          4.500000
# 4                 4       219         115            10          4.800000
# ...             ...       ...         ...           ...               ...
# 72758           151         7          15             7          8.628571
# 72759           152         6          14             7          8.603774
# 72760           154         4          13             7          8.635514
# 72761           155         3          12             7          8.611111
# 72762           161        -3          11             7          8.862385
#
#        required_run_rate                  BowlingTeam result
# 0              11.193277        Kolkata Knight Riders      0
# 1              11.237288        Kolkata Knight Riders      0
# 2              11.333333        Kolkata Knight Riders      0
# 3              11.379310        Kolkata Knight Riders      0
# 4              11.426087        Kolkata Knight Riders      0
# ...                  ...                          ...    ...
# 72758           2.800000  Royal Challengers Bangalore      1
# 72759           2.571429  Royal Challengers Bangalore      1
# 72760           1.846154  Royal Challengers Bangalore      1
# 72761           1.500000  Royal Challengers Bangalore      1
# 72762          -1.636364  Royal Challengers Bangalore      1
#
# [72763 rows x 31 columns]

# %%
delivery2 = spark.sql('select *,result(BattingTeam,WinningTeam) as result from delivery')

# %%
delivery2.columns
# Out:
# ['ID_M',
#  'City',
#  'WinningTeam',
#  'target_score',
#  'Team1',
#  'Team2',
#  'ID',
#  'innings',
#  'overs',
#  'ballnumber',
#  'batter',
#  'bowler',
#  'non-striker',
#  'extra_type',
#  'batsman_run',
#  'extras_run',
#  'total_run',
#  'non_boundary',
#  'isWicketDelivery',
#  'player_out',
#  'kind',
#  'fielders_involved',
#  'BattingTeam',
#  'current_score',
#  'runs_left',
#  'balls_left',
#  'wickets_left',
#  'current_run_rate',
#  'required_run_rate',
#  'BowlingTeam',
#  'result']

# %%
delivery2 = delivery2.drop('ID_M',
 'WinningTeam',
 'Team1',
 'Team2',
 'ID', 'total_run', 'current_score', 
 'innings',
 'overs',
 'ballnumber',
 'batter',
 'bowler',
 'non-striker',
 'extra_type',
 'batsman_run',
 'extras_run',
 'total_run_y',
 'non_boundary',
 'isWicketDelivery',
 'player_out',
 'kind',
 'fielders_involved')

# %%
delivery2.columns
# Out:
# ['City',
#  'target_score',
#  'BattingTeam',
#  'runs_left',
#  'balls_left',
#  'wickets_left',
#  'current_run_rate',
#  'required_run_rate',
#  'BowlingTeam',
#  'result']

# %%
delivery2 = delivery2.withColumnRenamed('City', 'city')

delivery2 = delivery2.withColumnRenamed('BattingTeam', 'batting_team')

delivery2 = delivery2.withColumnRenamed('BowlingTeam', 'bowling_team')

# %%
delivery2.columns
# Out:
# ['city',
#  'target_score',
#  'batting_team',
#  'runs_left',
#  'balls_left',
#  'wickets_left',
#  'current_run_rate',
#  'required_run_rate',
#  'bowling_team',
#  'result']

# %%
from pyspark.sql.functions import col,isnan,when,count

# %%
delivery2_col = delivery2.columns

# %%
delivery2.select([count(when(isnan(c) | col(c).isNull(),c)).alias(c) for c in delivery2_col]).show()
# Out:
# [Stage 82:>                                                         (0 + 1) / 1]
# +----+------------+------------+---------+----------+------------+----------------+-----------------+------------+------+
# |city|target_score|batting_team|runs_left|balls_left|wickets_left|current_run_rate|required_run_rate|bowling_team|result|
# +----+------------+------------+---------+----------+------------+----------------+-----------------+------------+------+
# |   0|           0|           0|        0|         0|           0|               0|              230|           0|     0|
# +----+------------+------------+---------+----------+------------+----------------+-----------------+------------+------+

# %%
delivery2.na.drop().toPandas()
# Out:
#             city  target_score                 batting_team  runs_left  \
# 0      Bangalore           223  Royal Challengers Bangalore        222
# 1      Bangalore           223  Royal Challengers Bangalore        221
# 2      Bangalore           223  Royal Challengers Bangalore        221
# 3      Bangalore           223  Royal Challengers Bangalore        220
# 4      Bangalore           223  Royal Challengers Bangalore        219
# ...          ...           ...                          ...        ...
# 72528  Ahmedabad           131               Gujarat Titans          7
# 72529  Ahmedabad           131               Gujarat Titans          7
# 72530  Ahmedabad           131               Gujarat Titans          6
# 72531  Ahmedabad           131               Gujarat Titans          4
# 72532  Ahmedabad           131               Gujarat Titans         -2
#
#        balls_left  wickets_left  current_run_rate  required_run_rate  \
# 0             119            10          6.000000          11.193277
# 1             118            10          6.000000          11.237288
# 2             117            10          4.000000          11.333333
# 3             116            10          4.500000          11.379310
# 4             115            10          4.800000          11.426087
# ...           ...           ...               ...                ...
# 72528          15             7          7.085714           2.800000
# 72529          14             7          7.018868           3.000000
# 72530          13             7          7.009346           2.769231
# 72531          12             7          7.055556           2.000000
# 72532          11             7          7.321101          -1.090909
#
#                 bowling_team  result
# 0      Kolkata Knight Riders       0
# 1      Kolkata Knight Riders       0
# 2      Kolkata Knight Riders       0
# 3      Kolkata Knight Riders       0
# 4      Kolkata Knight Riders       0
# ...                      ...     ...
# 72528       Rajasthan Royals       1
# 72529       Rajasthan Royals       1
# 72530       Rajasthan Royals       1
# 72531       Rajasthan Royals       1
# 72532       Rajasthan Royals       1
#
# [72533 rows x 10 columns]

# %%
delivery2 = delivery2.na.drop()

# %%
final_df = delivery2.toPandas()

# %%
final_df.isna().sum()
# Out:
# city                 0
# target_score         0
# batting_team         0
# runs_left            0
# balls_left           0
# wickets_left         0
# current_run_rate     0
# required_run_rate    0
# bowling_team         0
# result               0
# dtype: int64

# %%
final_df[np.isinf(final_df["current_run_rate"])].shape
# Out:
# (0, 10)

# %%
final_df[np.isinf(final_df["required_run_rate"])].shape
# Out:
# (0, 10)

# %%
final_df = final_df[final_df["required_run_rate"] >= 0]

# %% [markdown]
# ## Splitting training and test data

# %%
from sklearn.model_selection import train_test_split

# %%
# splitting dataframe based on independent and dependent variable(s)

X = final_df.iloc[:,:-1]
y = final_df.iloc[:, -1]

# %%
# creating training and testing dataframes

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train
# Out:
#                city  target_score                 batting_team  runs_left  \
# 36845        Raipur           139  Royal Challengers Bangalore         54
# 52012            NA           121          Sunrisers Hyderabad         34
# 10786        Jaipur           175             Rajasthan Royals        158
# 34056        Mumbai           200        Kolkata Knight Riders        123
# 5772   Johannesburg           150  Royal Challengers Bangalore         96
# ...             ...           ...                          ...        ...
# 49262       Kolkata           176             Rajasthan Royals         15
# 20674        Jaipur           125             Rajasthan Royals        106
# 21511       Chennai           186          Chennai Super Kings        141
# 50223     Bengaluru           176  Royal Challengers Bangalore        130
# 5209         Durban           140  Royal Challengers Bangalore         33
#
#        balls_left  wickets_left  current_run_rate  required_run_rate  \
# 36845          56             7          7.968750           5.785714
# 52012          46             6          7.054054           4.434783
# 10786          97             7          4.434783           9.773196
# 34056          72             8          9.625000          10.250000
# 5772           79             9          7.902439           7.291139
# ...           ...           ...               ...                ...
# 49262           9             4          8.702703          10.000000
# 20674         107            10          8.769231           5.943925
# 21511          90             9          9.000000           9.400000
# 50223          88             7          8.625000           8.863636
# 5209           25             7          6.757895           7.920000
#
#                       bowling_team
# 36845               Delhi Capitals
# 52012  Royal Challengers Bangalore
# 10786               Mumbai Indians
# 34056             Rajasthan Royals
# 5772                Mumbai Indians
# ...                            ...
# 49262        Kolkata Knight Riders
# 20674                 Punjab Kings
# 21511             Rajasthan Royals
# 50223          Sunrisers Hyderabad
# 5209         Kolkata Knight Riders
#
# [57824 rows x 9 columns]

# %%
y_train
# Out:
# 36845    1
# 52012    1
# 10786    0
# 34056    0
# 5772     1
#         ..
# 49262    1
# 20674    1
# 21511    1
# 50223    1
# 5209     1
# Name: result, Length: 57824, dtype: int32

# %% [markdown]
# ## Encoding

# %%
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import OneHotEncoder

# %%
# first three columns are of string datatypes, so, using one hot encoding

ct = ColumnTransformer([("ct",\
                         OneHotEncoder(sparse = False, drop = "first"), ["batting_team", "bowling_team", "city"])],\
                       remainder = "passthrough")

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score

# %%
# creating pipeline of one hot encoder and object of model

pipe = Pipeline(steps = [("step1", ct), ("step2", LogisticRegression(solver = "liblinear"))])

# %%
# training the model

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ct',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
X_train.describe()
# Out:
#        target_score     runs_left    balls_left  wickets_left  \
# count  57824.000000  57824.000000  57824.000000  57824.000000
# mean     165.834999     93.129566     62.848523      7.581662
# std       29.176328     49.601674     33.160530      2.138610
# min       63.000000     -3.000000     -2.000000      0.000000
# 25%      147.000000     54.000000     35.000000      6.000000
# 50%      166.000000     92.000000     63.000000      8.000000
# 75%      186.000000    130.000000     91.000000      9.000000
# max      247.000000    247.000000    119.000000     10.000000
#
#        current_run_rate  required_run_rate
# count      57824.000000       57824.000000
# mean           7.377223          10.635250
# std            2.243463          13.074181
# min            0.000000           0.000000
# 25%            6.240000           7.186813
# 50%            7.454545           8.918919
# 75%            8.625000          11.000000
# max           36.000000         714.000000

# %%
# predicting the output of test data using the created model

y_prediction_lr = pipe.predict(X_test)

# %%
# accuracy score of final model

accuracy_score(y_test, y_prediction_lr)
# Out:
# 0.817181987964308

# %%
# plotting confusion matrix

cm = confusion_matrix(y_test, y_prediction_lr, labels = pipe.classes_)

ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = pipe.classes_).plot()
plt.show()

# %%
print(classification_report(y_test, y_prediction_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.79      6343
#            1       0.83      0.85      0.84      8114
#
#     accuracy                           0.82     14457
#    macro avg       0.82      0.81      0.81     14457
# weighted avg       0.82      0.82      0.82     14457

# %% [markdown]
# ## Cross-Validation

# %%
from sklearn.model_selection import cross_validate

# %%
# performing cross validation

cross_val = cross_validate(pipe, X_train, y_train, cv = 10)

# %%
cross_val["test_score"]
# Out:
# array([0.8139374 , 0.8189521 , 0.81359156, 0.81532077, 0.82514701,
#        0.81217572, 0.82549291, 0.81995849, 0.81667243, 0.81857489])

# %%
cross_val["test_score"].mean()
# Out:
# 0.8179823278825153

# %%
X.shape
# Out:
# (72281, 9)

# %%
y.shape
# Out:
# (72281,)

# %%
pipe.predict_proba(X_test)[28]
# Out:
# array([0.02455988, 0.97544012])

# %% [markdown]
# ## Manual Shuffling

# %%
# now we have to shuffle the data because it can cause bias as it is grouped by id and innings

final_df1 = final_df.sample(final_df.shape[0])

# %%
X1 = final_df1.iloc[:,:-1]
y1 = final_df1.iloc[:, -1]

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size = 0.2, random_state = 1)

# %%
X_train1
# Out:
#             city  target_score                 batting_team  runs_left  \
# 35513      Delhi           165               Mumbai Indians        119
# 26640  Bangalore           156  Royal Challengers Bangalore        114
# 62925      Dubai           137               Delhi Capitals         90
# 27876  Bangalore           191             Rajasthan Royals         85
# 61520  Abu Dhabi           172          Chennai Super Kings        144
# ...          ...           ...                          ...        ...
# 61636  Abu Dhabi           136               Mumbai Indians        122
# 52062         NA           175             Rajasthan Royals        136
# 66177     Mumbai           166         Lucknow Super Giants         99
# 52500  Abu Dhabi           196        Kolkata Knight Riders        196
# 54401         NA           224             Rajasthan Royals        127
#
#        balls_left  wickets_left  current_run_rate  required_run_rate  \
# 35513          94             9         10.615385           7.595745
# 26640          73             7          5.361702           9.369863
# 62925          91             9          9.724138           5.934066
# 27876          39             5          7.851852          13.076923
# 61520          98            10          7.636364           8.816327
# ...           ...           ...               ...                ...
# 61636         105            10          5.600000           6.971429
# 52062          83             7          6.324324           9.831325
# 66177          53             6          6.000000          11.207547
# 52500         118            10          0.000000           9.966102
# 54401          70             9         11.640000          10.885714
#
#                       bowling_team
# 35513               Delhi Capitals
# 26640          Sunrisers Hyderabad
# 62925          Chennai Super Kings
# 27876  Royal Challengers Bangalore
# 61520        Kolkata Knight Riders
# ...                            ...
# 61636                 Punjab Kings
# 52062        Kolkata Knight Riders
# 66177             Rajasthan Royals
# 52500               Mumbai Indians
# 54401                 Punjab Kings
#
# [57824 rows x 9 columns]

# %%
y_train1
# Out:
# 35513    0
# 26640    1
# 62925    1
# 27876    1
# 61520    1
#         ..
# 61636    1
# 52062    0
# 66177    0
# 52500    0
# 54401    1
# Name: result, Length: 57824, dtype: int32

# %% [markdown]
# ## Encoding

# %%
ct1 = ColumnTransformer([("ct1",\
                         OneHotEncoder(sparse = False, drop = "first"), ["batting_team", "bowling_team", "city"])],\
                       remainder = "passthrough")

# %% [markdown]
# ## Logistic Regression

# %%
pipe1 = Pipeline(steps = [("step1", ct1), ("step2", LogisticRegression(solver = "liblinear"))])

# %%
pipe1.fit(X_train1, y_train1)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ct1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
X_train1.describe()
# Out:
#        target_score     runs_left    balls_left  wickets_left  \
# count  57824.000000  57824.000000  57824.000000  57824.000000
# mean     165.743757     93.150923     62.917785      7.588752
# std       29.220813     49.626700     33.161985      2.133964
# min       63.000000     -3.000000     -2.000000      0.000000
# 25%      147.000000     54.000000     35.000000      6.000000
# 50%      166.000000     92.000000     64.000000      8.000000
# 75%      186.000000    130.000000     92.000000      9.000000
# max      247.000000    247.000000    119.000000     10.000000
#
#        current_run_rate  required_run_rate
# count      57824.000000       57824.000000
# mean           7.377337          10.601222
# std            2.241926          12.645959
# min            0.000000           0.000000
# 25%            6.235294           7.180328
# 50%            7.450549           8.916667
# 75%            8.625000          11.000000
# max           36.000000         714.000000

# %%
y_prediction_lr1 = pipe.predict(X_test1)

# %%
accuracy_score(y_test1, y_prediction_lr1)
# Out:
# 0.8169744760323718

# %%
cm1 = confusion_matrix(y_test1, y_prediction_lr1, labels = pipe1.classes_)

ConfusionMatrixDisplay(confusion_matrix = cm1, display_labels = pipe.classes_).plot()
plt.show()

# %%
print(classification_report(y_test1, y_prediction_lr1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      6467
#            1       0.82      0.85      0.84      7990
#
#     accuracy                           0.82     14457
#    macro avg       0.82      0.81      0.81     14457
# weighted avg       0.82      0.82      0.82     14457

# %% [markdown]
# ## Cross-Validation

# %%
cross_val1 = cross_validate(pipe1, X_train1, y_train1, cv = 10)

# %%
cross_val1["test_score"]
# Out:
# array([0.82171883, 0.8198167 , 0.82379388, 0.82638769, 0.81961259,
#        0.81788309, 0.81269457, 0.81563473, 0.82289865, 0.80837081])

# %%
cross_val1["test_score"].mean()
# Out:
# 0.8188811532842989

# %%
X1.shape
# Out:
# (72281, 9)

# %%
y1.shape
# Out:
# (72281,)

# %%
pipe1.predict_proba(X_test1)[5]
# Out:
# array([0.55110277, 0.44889723])

# %% [markdown]
# ## Pickling

# %%
import pickle

# %%
# serializing the code for deployment

pickle.dump(pipe, open("PySpark_LR.pkl", "wb"))
